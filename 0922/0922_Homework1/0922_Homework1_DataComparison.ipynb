# %%
import pandas as pd

student = pd.read_csv("110_student.csv")

student_1 = list(student['總計'])
student_1
# Out:
# ['948',
#  '3,974',
#  '9,556',
#  '1,632',
#  '1,663',
#  '5,570',
#  '8,888',
#  '1',
#  '1,366',
#  '3,666',
#  '10,720',
#  '16,906',
#  '1,631',
#  '1,358',
#  '4,359',
#  '8,313',
#  '2,134',
#  '1,872',
#  '7,239',
#  '11,758',
#  '1,537',
#  '966',
#  '3,477',
#  '8,069',
#  '1,706',
#  '936',
#  '2,653',
#  '7,547',
#  '8,431',
#  '1,781',
#  '1,007',
#  '3,620',
#  '6,068',
#  '1,433',
#  '823',
#  '3,180',
#  '4,804',
#  '1,090',
#  '330',
#  '1,430',
#  '6,072',
#  '647',
#  '1',
#  '588',
#  '549',
#  '2,821',
#  '6,414',
#  '1,428',
#  '458',
#  '1,442',
#  '3,793',
#  '1,454',
#  '506',
#  '1,655',
#  '4,942',
#  '1,356',
#  '212',
#  '1,404',
#  '5,956',
#  '595',
#  '2,069',
#  '195',
#  '1,278',
#  '7,516',
#  '929',
#  '1,887',
#  '30',
#  '656',
#  '4,534',
#  '550',
#  '146',
#  '423',
#  '1,418',
#  '7,847',
#  '563',
#  '342',
#  '808',
#  '4,606',
#  '486',
#  '1,063',
#  '3,738',
#  '5,583',
#  '59',
#  '786',
#  '427',
#  '1,955',
#  '6,287',
#  '195',
# ...
