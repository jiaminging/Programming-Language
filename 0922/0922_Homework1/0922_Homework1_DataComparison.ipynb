# %%
import pandas as pd


student = pd.read_csv("110_student.csv")
land = pd.read_csv("110_land.csv")

student
# Out:
#      學校代碼        學校名稱 日間∕進修別   等級別     總計    男生計    女生計 一年級男生  一年級女生 二年級男生  \
# 0       1      國立政治大學    D 日  D 博士    948    537    411    88     67    81
# 1       1      國立政治大學    D 日  M 碩士  3,974  1,828  2,146   624    729   591
# 2       1      國立政治大學    D 日  B 學士  9,556  3,920  5,636   900  1,303   920
# 3       1      國立政治大學    N 職  M 碩士  1,632    779    853   227    294   239
# 4       2      國立清華大學    D 日  D 博士  1,663  1,192    471   248    114   193
# ..    ...         ...    ...   ...    ...    ...    ...   ...    ...   ...
# 786  1293  崇仁醫護管理專科學校    D 日  5 五專  3,209    445  2,764   110    519    95
# 787  3002      臺北市立大學    D 日  D 博士    220     95    125    16     18    13
# 788  3002      臺北市立大學    D 日  M 碩士  1,348    447    901   144    292   125
# 789  3002      臺北市立大學    D 日  B 學士  5,345  2,363  2,982   575    727   552
# 790  3002      臺北市立大學    N 職  M 碩士  1,201    316    885   105    280    96
#
# ...
