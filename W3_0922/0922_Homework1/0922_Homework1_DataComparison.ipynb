# %%
#匯入csv

import pandas as pd

album = pd.read_csv("Album_example.csv")

album
# Out:
#                                    Album                      Artist  Year  \
# 0                         Whats Going On                Marvin Gaye   1971
# 1                             Pet Sounds             The Beach Boys   1966
# 2               Songs in the Key of Life              Stevie Wonder   1976
# 3                             Abbey Road                The Beatles   1969
# 4                                 Rumors               Fleetwood Mac  1977
# 5                            Purple Rain  Prince and the Revolution   1984
# 6                    Are You Experienced                Jimi Hendrix  1967
# 7  Sgt. Pepper’s Lonely Hearts Club Band                The Beatles   1967
# 8                            White Album                 The Beatles  1968
# 9                               Revolver                 The Beatles  1966
#
#          Record
# 0  Tamla/Motown
# 1       Capitol
# 2  Tamla/Motown
# 3         Apple
# 4  Warner Bros.
# 5  Warner Bros.
# 6         Track
# ...

# %%
ls_Album = list(album["Album"])
ls_Artist = list(album["Artist"])
ls_Year = list(album["Year"])
ls_Record = list(album["Record"])
